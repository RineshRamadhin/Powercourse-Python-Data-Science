# %% [markdown]
# # Data ingest

# %% [markdown]
# This notebook will load in various COVID-19 datasets, combine them using Python methods and export them in full to the datasets folder. It will also create a sample of the final export file to reduce time in following analysis notebooks.

# %% [markdown]
# ### Imports

# %% [markdown]
# First let's load in some packages.

# %%
from __future__ import print_function, division
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data ingest

# %% [markdown]
# Next let's load all the data into dataframes.

# %%
owid = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')
countries = pd.read_csv('https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv')
google = pd.read_csv('https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv', header=0, na_values = [''])
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### Data merging

# %% [markdown]
# Now let's prepare the datasets and merge them into a single dataframe.

# %%
df = pd.merge(owid, countries[['alpha-2', 'alpha-3']], how="inner", left_on='iso_code', right_on='alpha-3')

# %%
del df['alpha-3']
df = df.rename(columns={"iso_code": "alpha-3"})

# %%
df = pd.merge(df, google, how="inner", left_on=['alpha-2', 'date'], right_on=['country_region_code', 'date'])

# %%
del df['country_region_code']

# %% [markdown]
# ### Let's quickly explore!

# %%
df.head()
# Out:
#   alpha-3 continent     location        date  total_cases  new_cases  \
# 0     AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1     AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 2     AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 3     AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 4     AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.026                  0.026
# 1                    0.026                  0.026
# 2                    0.026                  0.000
# 3                    0.026                  0.000
# 4                    0.026                  0.000
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                     NaN                              NaN                NaN
# 1                     NaN                              NaN                NaN
# 2                     NaN                              NaN                NaN
# 3                     NaN                              NaN                NaN
# 4                     NaN                              NaN                NaN
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0           NaN                       NaN            NaN
# 1           NaN                       NaN            NaN
# 2           NaN                       NaN            NaN
# 3           NaN                       NaN            NaN
# 4           NaN                       NaN            NaN
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#    weekly_hosp_admissions_per_million  new_tests  total_tests  \
# 0                                 NaN        NaN          NaN
# 1                                 NaN        NaN          NaN
# 2                                 NaN        NaN          NaN
# 3                                 NaN        NaN          NaN
# 4                                 NaN        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case tests_units  \
# 0                              NaN            NaN             NaN         NaN
# 1                              NaN            NaN             NaN         NaN
# 2                              NaN            NaN             NaN         NaN
# 3                              NaN            NaN             NaN         NaN
# 4                              NaN            NaN             NaN         NaN
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                 NaN                NaN                      NaN
# 1                 NaN                NaN                      NaN
# 2                 NaN                NaN                      NaN
# 3                 NaN                NaN                      NaN
# 4                 NaN                NaN                      NaN
#
#    new_vaccinations  new_vaccinations_smoothed  \
# 0               NaN                        NaN
# 1               NaN                        NaN
# 2               NaN                        NaN
# 3               NaN                        NaN
# 4               NaN                        NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  new_vaccinations_smoothed_per_million  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#    stringency_index  population  population_density  median_age  \
# 0              8.33  38928341.0              54.422        18.6
# 1              8.33  38928341.0              54.422        18.6
# 2              8.33  38928341.0              54.422        18.6
# 3              8.33  38928341.0              54.422        18.6
# 4              8.33  38928341.0              54.422        18.6
#
#    aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 0          2.581          1.337        1803.987              NaN
# 1          2.581          1.337        1803.987              NaN
# 2          2.581          1.337        1803.987              NaN
# 3          2.581          1.337        1803.987              NaN
# 4          2.581          1.337        1803.987              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                597.029                 9.59             NaN           NaN
# 1                597.029                 9.59             NaN           NaN
# 2                597.029                 9.59             NaN           NaN
# 3                597.029                 9.59             NaN           NaN
# 4                597.029                 9.59             NaN           NaN
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                  37.746                         0.5            64.83
# 1                  37.746                         0.5            64.83
# 2                  37.746                         0.5            64.83
# 3                  37.746                         0.5            64.83
# 4                  37.746                         0.5            64.83
#
#    human_development_index alpha-2 country_region sub_region_1 sub_region_2  \
# 0                    0.511      AF    Afghanistan          NaN          NaN
# 1                    0.511      AF    Afghanistan          NaN          NaN
# 2                    0.511      AF    Afghanistan          NaN          NaN
# 3                    0.511      AF    Afghanistan          NaN          NaN
# 4                    0.511      AF    Afghanistan          NaN          NaN
#
#                 metro_area iso_3166_2_code  census_fips_code  \
# 0                      NaN             NaN               NaN
# 1  Kabul Metropolitan Area             NaN               NaN
# 2                      NaN             NaN               NaN
# 3  Kabul Metropolitan Area             NaN               NaN
# 4                      NaN             NaN               NaN
#
#                       place_id  \
# 0  ChIJbQL_-LZu0TgReNqWvg1GtfM
# 1  ChIJ5U8S6F5v0TgREM8nxN8oCHA
# 2  ChIJbQL_-LZu0TgReNqWvg1GtfM
# 3  ChIJ5U8S6F5v0TgREM8nxN8oCHA
# 4  ChIJbQL_-LZu0TgReNqWvg1GtfM
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                3.0
# 1                                               -2.0
# 2                                                2.0
# 3                                               -2.0
# 4                                               -1.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               13.0
# 1                                               15.0
# 2                                                5.0
# 3                                                7.0
# 4                                                5.0
#
#    parks_percent_change_from_baseline  \
# 0                                 4.0
# 1                                 1.0
# 2                                 1.0
# 3                                 4.0
# 4                                 2.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            9.0
# 1                                            8.0
# 2                                            9.0
# 3                                            8.0
# 4                                            3.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      7.0
# 1                                      6.0
# 2                                      7.0
# 3                                      5.0
# 4                                      5.0
#
#    residential_percent_change_from_baseline
# 0                                       0.0
# 1                                      -1.0
# 2                                       0.0
# 3                                       1.0
# 4                                       1.0

# %%
df.shape
# Out:
# (4342866, 73)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4342866 entries, 0 to 4342865
# Data columns (total 73 columns):
#  #   Column                                              Dtype
# ---  ------                                              -----
#  0   alpha-3                                             object
#  1   continent                                           object
#  2   location                                            object
#  3   date                                                object
#  4   total_cases                                         float64
#  5   new_cases                                           float64
#  6   new_cases_smoothed                                  float64
#  7   total_deaths                                        float64
#  8   new_deaths                                          float64
#  9   new_deaths_smoothed                                 float64
#  10  total_cases_per_million                             float64
#  11  new_cases_per_million                               float64
#  12  new_cases_smoothed_per_million                      float64
#  13  total_deaths_per_million                            float64
#  14  new_deaths_per_million                              float64
#  15  new_deaths_smoothed_per_million                     float64
#  16  reproduction_rate                                   float64
#  17  icu_patients                                        float64
#  18  icu_patients_per_million                            float64
#  19  hosp_patients                                       float64
#  20  hosp_patients_per_million                           float64
#  21  weekly_icu_admissions                               float64
#  22  weekly_icu_admissions_per_million                   float64
#  23  weekly_hosp_admissions                              float64
#  24  weekly_hosp_admissions_per_million                  float64
#  25  new_tests                                           float64
#  26  total_tests                                         float64
#  27  total_tests_per_thousand                            float64
#  28  new_tests_per_thousand                              float64
#  29  new_tests_smoothed                                  float64
#  30  new_tests_smoothed_per_thousand                     float64
#  31  positive_rate                                       float64
#  32  tests_per_case                                      float64
#  33  tests_units                                         object
#  34  total_vaccinations                                  float64
#  35  people_vaccinated                                   float64
#  36  people_fully_vaccinated                             float64
#  37  new_vaccinations                                    float64
#  38  new_vaccinations_smoothed                           float64
#  39  total_vaccinations_per_hundred                      float64
#  40  people_vaccinated_per_hundred                       float64
#  41  people_fully_vaccinated_per_hundred                 float64
#  42  new_vaccinations_smoothed_per_million               float64
#  43  stringency_index                                    float64
#  44  population                                          float64
#  45  population_density                                  float64
#  46  median_age                                          float64
#  47  aged_65_older                                       float64
#  48  aged_70_older                                       float64
#  49  gdp_per_capita                                      float64
#  50  extreme_poverty                                     float64
#  51  cardiovasc_death_rate                               float64
#  52  diabetes_prevalence                                 float64
#  53  female_smokers                                      float64
#  54  male_smokers                                        float64
#  55  handwashing_facilities                              float64
#  56  hospital_beds_per_thousand                          float64
#  57  life_expectancy                                     float64
#  58  human_development_index                             float64
#  59  alpha-2                                             object
#  60  country_region                                      object
#  61  sub_region_1                                        object
#  62  sub_region_2                                        object
#  63  metro_area                                          object
#  64  iso_3166_2_code                                     object
#  65  census_fips_code                                    float64
#  66  place_id                                            object
#  67  retail_and_recreation_percent_change_from_baseline  float64
#  68  grocery_and_pharmacy_percent_change_from_baseline   float64
#  69  parks_percent_change_from_baseline                  float64
#  70  transit_stations_percent_change_from_baseline       float64
#  71  workplaces_percent_change_from_baseline             float64
#  72  residential_percent_change_from_baseline            float64
# dtypes: float64(61), object(12)
# memory usage: 2.4+ GB

# %% [markdown]
# ### Data export

# %% [markdown]
# Finally let's export them to CSV so we can use them in then upcoming notebooks.

# %%
df.sample(n = 50000).to_csv('../datasets/sdf.csv')

# %%
locations = df['location'].unique()
pd.DataFrame(locations).to_csv('../datasets/locations.csv')
for location in locations:
    df[df['location'] == location].to_csv(f'../datasets/df_location_{location}.csv')

# %%
continents = df['continent'].unique()
pd.DataFrame(continents).to_csv('../datasets/continents.csv')
for continent in continents:
    df[df['continent'] == continent].to_csv(f'../datasets/df_continent_{continent}.csv')
